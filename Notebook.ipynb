-- %% [markdown]
-- # COVID-19 Data Analysis for Vaccination Program in the Workplace Environment
--
-- ## **Encouraging employees to take vaccination with proven analysis**
--
-- ## Source Data: [https://github.com/owid/covid-19-data/tree/23437bc185de9f34573cf25eb1b08016d449951c](https://github.com/owid/covid-19-data/tree/23437bc185de9f34573cf25eb1b08016d449951c)
--
-- ### _**Citations:**_
--
-- <span style="color: rgb(87, 96, 106); font-family: -apple-system, BlinkMacSystemFont, &quot;Segoe UI&quot;, Helvetica, Arial, sans-serif, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;; font-size: 16px; background-color: rgb(255, 255, 255);">1. Mathieu, E., Ritchie, H., Ortiz-Ospina, E.&nbsp;</span> _et al._ <span style="color: rgb(87, 96, 106); font-family: -apple-system, BlinkMacSystemFont, &quot;Segoe UI&quot;, Helvetica, Arial, sans-serif, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;; font-size: 16px; background-color: rgb(255, 255, 255);">&nbsp;A global database of COVID-19 vaccinations.&nbsp;</span> _Nat Hum Behav_ <span style="color: rgb(87, 96, 106); font-family: -apple-system, BlinkMacSystemFont, &quot;Segoe UI&quot;, Helvetica, Arial, sans-serif, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;; font-size: 16px; background-color: rgb(255, 255, 255);">&nbsp;(2021).&nbsp;</span> [https://doi.org/10.1038/s41562-021-01122-8](https://doi.org/10.1038/s41562-021-01122-8)
--
-- <span style="color: rgb(87, 96, 106); background-color: rgb(255, 255, 254);">2.&nbsp;</span> <span style="color: rgb(87, 96, 106); font-family: -apple-system, BlinkMacSystemFont, &quot;Segoe UI&quot;, Helvetica, Arial, sans-serif, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;; font-size: 16px; background-color: rgb(255, 255, 255);">Hasell, J., Mathieu, E., Beltekian, D.&nbsp;</span> _et al._ <span style="color: rgb(87, 96, 106); font-family: -apple-system, BlinkMacSystemFont, &quot;Segoe UI&quot;, Helvetica, Arial, sans-serif, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;; font-size: 16px; background-color: rgb(255, 255, 255);">&nbsp;A cross-country database of COVID-19 testing.&nbsp;</span> _Sci Data_ <span style="box-sizing: border-box; font-weight: 600; color: rgb(87, 96, 106); font-family: -apple-system, BlinkMacSystemFont, &quot;Segoe UI&quot;, Helvetica, Arial, sans-serif, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;; font-size: 16px; background-color: rgb(255, 255, 255);">7</span><span style="color: rgb(87, 96, 106); font-family: -apple-system, BlinkMacSystemFont, &quot;Segoe UI&quot;, Helvetica, Arial, sans-serif, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;; font-size: 16px; background-color: rgb(255, 255, 255);">, 345 (2020).&nbsp;</span> [https://doi.org/10.1038/s41597-020-00688-8](https://doi.org/10.1038/s41597-020-00688-8)

-- %% [markdown]
-- # Introduction: What is COVID-19?
--
-- ## <span style="color:rgb(60, 66, 69);font-family:Arial, Helvetica, sans-serif;font-size:16px;">Coronavirus disease (COVID-19) is an infectious disease caused by the SARS-CoV-2 virus.</span>
--
-- ### <span style="color:rgb(60, 66, 69);font-family:Arial, Helvetica, sans-serif;font-size:16px;"><i><b>Source</b>:&nbsp;</i></span> <span style="font-size:16px;background-color:yellow;"><i><a href="https://www.who.int/health-topics/coronavirus#tab=tab_1" title="https://www.who.int/health-topics/coronavirus#tab=tab_1" rel="nofollow">https://www.who.int/health-topics/coronavirus#tab=tab_1</a></i></span>
--
-- ![Pin on Covid19](https://i.pinimg.com/originals/a8/d8/66/a8d866c87e75ae65af8a3f167ee1e8f6.gif)
--
-- ### **Membranes**
--
-- ![](attachment:image.png)

-- %% [markdown]
-- ### **1\. Top 10 countries with most Covid cases**

-- %%
SELECT top 10
      [location]
      ,sum([total_cases]) as [Total_cases]
      --,sum([total_deaths]) as [Total_deaths]
  FROM [COVID].[dbo].[owid-covid-data]
  group by [location]
  order by [location] asc, [total_cases] DESC
-- Out:
-- ...
-- (10 rows affected)
-- Total execution time: 00:00:00.065
-- <table><tr><th>location</th><th>Total_cases</th></tr><tr><td>Afghanistan</td><td>50395620</td></tr><tr><td>Africa</td><td>2665290627</td></tr><tr><td>Albania</td><td>58106517</td></tr><tr><td>Algeria</td><td>71084767</td></tr><tr><td>Andorra</td><td>6167837</td></tr><tr><td>Angola</td><td>17469086</td></tr><tr><td>Anguilla</td><td>159798</td></tr><tr><td>Antigua and Barbuda</td><td>784604</td></tr><tr><td>Argentina</td><td>1682455167</td></tr><tr><td>Armenia</td><td>105982761</td></tr></table>

-- %% [markdown]
-- ### **2\. Information on Covid vaccinations based on the continent**

-- %%
SELECT
      [continent]
	  , sum([total_vaccinations]) as [Total_vaccinations]
	  , sum([people_vaccinated]) as [People_partially_vaccinated]
	  , sum([people_fully_vaccinated]) as [People_fully_vaccinated]
	  , sum([population]) as [Population]
     FROM [COVID].[dbo].[owid-covid-latest]
	 where [continent] is not null
  group by [continent]
-- Out:
-- ...
-- (6 rows affected)
-- Total execution time: 00:00:00.007
-- <table><tr><th>continent</th><th>Total_vaccinations</th><th>People_partially_vaccinated</th><th>People_fully_vaccinated</th><th>Population</th></tr><tr><td>Africa</td><td>320232232</td><td>193704468</td><td>128567944</td><td>1371693391</td></tr><tr><td>Asia</td><td>6404846341</td><td>3090078879</td><td>2482980896</td><td>4646498129</td></tr><tr><td>Europe</td><td>1151292865</td><td>491211613</td><td>465066350</td><td>750683291</td></tr><tr><td>North America</td><td>706497858</td><td>329118762</td><td>277602253</td><td>592834825</td></tr><tr><td>Oceania</td><td>57862879</td><td>26696207</td><td>25390976</td><td>43172934</td></tr><tr><td>South America</td><td>642790470</td><td>314608020</td><td>271655105</td><td>433953688</td></tr></table>

-- %% [markdown]
-- ### **3\. Analyze people vaccinated in united states per state**

-- %%
SELECT
      [location]
      ,sum([total_vaccinations]) as [total_vaccinations]
      ,sum([people_vaccinated]) as [people_vaccinated_partially]
      ,sum([people_fully_vaccinated]) as [people_fully_vaccinated]
  FROM [COVID].[dbo].[USA_state_vaccinations]
  group by [location]
  order by [location] asc
-- Out:
-- ...
-- (65 rows affected)
-- Total execution time: 00:00:00.026
-- ...

-- %% [markdown]
-- ### **4\. Post vaccination cases in state of California- Sample State California Data**

-- %%
SELECT 
      area,
      sum([unvaccinated_cases]) as [unvaccinated_cases]
      ,sum([vaccinated_cases]) as [vaccinated_cases]
  FROM [COVID].[dbo].[covid-19-post-vaccination-statewide-stats]
  group by area
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.004
-- <table><tr><th>area</th><th>unvaccinated_cases</th><th>vaccinated_cases</th></tr><tr><td>California</td><td>1128251</td><td>403839</td></tr></table>

-- %% [markdown]
-- ### **5\. Unvaccinated vs Vaccinated cases in the state of California**

-- %%
Select area, sum([unvaccinated_hosp]) as [unvaccinated_hosp]
      ,sum([vaccinated_hosp]) as [vaccinated_hosp]
      ,sum([unvaccinated_deaths]) as [unvaccinated_deaths]
      ,sum([vaccinated_deaths]) as [vaccinated_deaths]
       FROM [COVID].[dbo].[covid-19-post-vaccination-statewide-stats]
  group by area
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.004
-- <table><tr><th>area</th><th>unvaccinated_hosp</th><th>vaccinated_hosp</th><th>unvaccinated_deaths</th><th>vaccinated_deaths</th></tr><tr><td>California</td><td>79762</td><td>13953</td><td>19243</td><td>1996</td></tr></table>

-- %% [markdown]
-- ### **5\. Vaccination Manufacturers and counts- showing the Vaccine availability across the country**

-- %%
SELECT 
      [vaccine],
	  SUM(CONVERT(BIGINT, total_vaccinations)) AS [total_vaccinations]
  FROM [COVID].[dbo].[vaccinations-by-manufacturer]
  group by [vaccine]
  order by [total_vaccinations] desc
-- Out:
-- (8 rows affected)
-- Total execution time: 00:00:00.019
-- <table><tr><th>vaccine</th><th>total_vaccinations</th></tr><tr><td>Pfizer/BioNTech</td><td>237847759987</td></tr><tr><td>Moderna</td><td>67817111098</td></tr><tr><td>Oxford/AstraZeneca</td><td>31875594137</td></tr><tr><td>Sinovac</td><td>10286921161</td></tr><tr><td>Johnson&amp;Johnson</td><td>8877406138</td></tr><tr><td>Sinopharm/Beijing</td><td>2819598509</td></tr><tr><td>Sputnik V</td><td>560475520</td></tr><tr><td>CanSino</td><td>164078929</td></tr></table>

-- %% [markdown]
-- ## **Mask use interviews done in United states**
--
-- ### **1.** **Top 10 counties who said** ****ALWAYS:**** **The estimated share of people in this county who would say Always in response to the question “How often do you wear a mask in public when you expect to be within six feet of another person?”**
--
-- **Citations:**
--
-- 1. [https://www.nytimes.com/interactive/2020/07/17/upshot/coronavirus-face-mask-map.html](https://www.nytimes.com/interactive/2020/07/17/upshot/coronavirus-face-mask-map.html)
-- 2. [https://www.nytimes.com/interactive/2020/07/17/upshot/coronavirus-face-mask-map.html](https://www.nytimes.com/interactive/2020/07/17/upshot/coronavirus-face-mask-map.html)
-- 3. [https://github.com/nytimes/covid-19-data](https://github.com/nytimes/covid-19-data)

-- %%
  SELECT  top 10 countyname
      ,[ALWAYS]
  FROM [COVID].[dbo].[mask-use-by-county] a
   join [dbo].[Countynames] b
  on a. [CountyFP]=b.[CountyFP]
order by [ALWAYS] desc
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.009
-- <table><tr><th>countyname</th><th>ALWAYS</th></tr><tr><td>East Hartland, Connecticut</td><td>0.8889999985694885</td></tr><tr><td>Montgomery, Alabama</td><td>0.8840000033378601</td></tr><tr><td>New britain, Connecticut</td><td>0.8799999952316284</td></tr><tr><td>Ecorse, Michigan</td><td>0.8799999952316284</td></tr><tr><td>Inkster, Michigan</td><td>0.8769999742507935</td></tr><tr><td>Bryceville, Florida</td><td>0.871999979019165</td></tr><tr><td>East Berlin, Connecticut</td><td>0.8650000095367432</td></tr><tr><td>Seneca County, New York</td><td>0.8640000224113464</td></tr><tr><td>Montgomery, Alabama</td><td>0.8610000014305115</td></tr><tr><td>Kanawha County, West Virginia</td><td>0.8569999933242798</td></tr></table>

-- %% [markdown]
-- ### **2.** **Top 10 counties who said** <span style="font-size: 16.38px;"><b><strong>NEVER</strong>: The estimated share of people in this county who would say <strong>never</strong> in response to the question “How often do you wear a mask in public when you expect to be within six feet of another person?”&nbsp;&nbsp;</b></span>
--
-- **Citations:**
--
-- 1. [https://www.nytimes.com/interactive/2020/07/17/upshot/coronavirus-face-mask-map.html](https://www.nytimes.com/interactive/2020/07/17/upshot/coronavirus-face-mask-map.html)
-- 2. [https://www.nytimes.com/interactive/2020/07/17/upshot/coronavirus-face-mask-map.html](https://www.nytimes.com/interactive/2020/07/17/upshot/coronavirus-face-mask-map.html)
-- 3. [https://github.com/nytimes/covid-19-data](https://github.com/nytimes/covid-19-data)

-- %%
SELECT top 10 Countyname
      ,[NEVER]
  FROM [COVID].[dbo].[mask-use-by-county] a
   join [dbo].[Countynames] b
  on a.[CountyFP]=b.[CountyFP]
  order by [NEVER] desc
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.007
-- <table><tr><th>Countyname</th><th>NEVER</th></tr><tr><td>Breedsville, Michigan</td><td>0.4320000112056732</td></tr><tr><td>Richland County, South Carolina</td><td>0.4189999997615814</td></tr><tr><td>Delaware County, Pennsylvania</td><td>0.3409999907016754</td></tr><tr><td>Benton Harbor, Michigan</td><td>0.33500000834465027</td></tr><tr><td>Jackson County, Minnesota</td><td>0.32499998807907104</td></tr><tr><td>Aiken County, South Carolina</td><td>0.31299999356269836</td></tr><tr><td>Dade County, Missouri</td><td>0.31200000643730164</td></tr><tr><td>Saint Paul, Minnesota</td><td>0.31200000643730164</td></tr><tr><td>Columbia, South Carolina</td><td>0.3089999854564667</td></tr><tr><td>Clinchfield, Georgia</td><td>0.30300000309944153</td></tr></table>

-- %% [markdown]
-- ## **Wear Mask and Save your Life!**
--
-- ![How To Wear A Mask Cover Your Nose GIF - How To Wear A Mask Wear A Mask Cover Your Nose GIFs](https://c.tenor.com/8SJU6xFi80sAAAAC/how-to-wear-a-mask-wear-a-mask.gif)

-- %% [markdown]
-- ## **Data cleaning**
--
-- ### In this below query results we see the covid cases based on the financial status, which was not supposed to be here. We do not encourage our analysis to be done based on the financial status of the population.

-- %%
SELECT top 20
      [location]
      ,sum([total_cases]) as [Total_cases]
      ,sum([total_deaths]) as [Total_deaths]
  FROM [COVID].[dbo].[owid-covid-data]
  where location <> 'world'
  group by [location]
  order by [total_cases] DESC
-- Out:
-- ...
-- (20 rows affected)
-- Total execution time: 00:00:00.053
-- ...

-- %% [markdown]
-- ### Cleaning the records related to High income, upper middle income and lower middle income. Importing the records into new table before deleting in the source table.

-- %%
SELECT [iso_code]
      ,[continent]
      ,[location]
      ,[date]
      ,[total_cases]
      ,[new_cases]
      ,[new_cases_smoothed]
      ,[total_deaths]
      ,[new_deaths]
      ,[new_deaths_smoothed]
      ,[total_cases_per_million]
      ,[new_cases_per_million]
      ,[new_cases_smoothed_per_million]
      ,[total_deaths_per_million]
      ,[new_deaths_per_million]
      ,[new_deaths_smoothed_per_million]
      ,[reproduction_rate]
      ,[icu_patients]
      ,[icu_patients_per_million]
      ,[hosp_patients]
      ,[hosp_patients_per_million]
      ,[weekly_icu_admissions]
      ,[weekly_icu_admissions_per_million]
      ,[weekly_hosp_admissions]
      ,[weekly_hosp_admissions_per_million]
      ,[new_tests]
      ,[total_tests]
      ,[total_tests_per_thousand]
      ,[new_tests_per_thousand]
      ,[new_tests_smoothed]
      ,[new_tests_smoothed_per_thousand]
      ,[positive_rate]
      ,[tests_per_case]
      ,[tests_units]
      ,[total_vaccinations]
      ,[people_vaccinated]
      ,[people_fully_vaccinated]
      ,[total_boosters]
      ,[new_vaccinations]
      ,[new_vaccinations_smoothed]
      ,[total_vaccinations_per_hundred]
      ,[people_vaccinated_per_hundred]
      ,[people_fully_vaccinated_per_hundred]
      ,[total_boosters_per_hundred]
      ,[new_vaccinations_smoothed_per_million]
      ,[new_people_vaccinated_smoothed]
      ,[new_people_vaccinated_smoothed_per_hundred]
      ,[stringency_index]
      ,[population]
      ,[population_density]
      ,[median_age]
      ,[aged_65_older]
      ,[aged_70_older]
      ,[gdp_per_capita]
      ,[extreme_poverty]
      ,[cardiovasc_death_rate]
      ,[diabetes_prevalence]
      ,[female_smokers]
      ,[male_smokers]
      ,[handwashing_facilities]
      ,[hospital_beds_per_thousand]
      ,[life_expectancy]
      ,[human_development_index]
      ,[excess_mortality_cumulative_absolute]
      ,[excess_mortality_cumulative]
      ,[excess_mortality]
      ,[excess_mortality_cumulative_per_million]
	  into Financialstatus
  FROM [COVID].[dbo].[owid-covid-data]
  where location in ('High income','Upper middle income','Lower middle income')
-- Out:
-- (2175 rows affected)
-- Total execution time: 00:00:00.137

-- %% [markdown]
-- ### Deleting the financial status data from the source table using the filter on location <span style="font-family:Consolas, &quot;Courier New&quot;, monospace;font-size:12px;white-space:pre;color:rgb(163, 21, 21);">'High&nbsp;income'</span><span style="color:rgb(33, 33, 33);font-family:Consolas, &quot;Courier New&quot;, monospace;font-size:12px;white-space:pre;">,</span><span style="font-family:Consolas, &quot;Courier New&quot;, monospace;font-size:12px;white-space:pre;color:rgb(163, 21, 21);">'Upper&nbsp;middle&nbsp;income'</span><span style="color:rgb(33, 33, 33);font-family:Consolas, &quot;Courier New&quot;, monospace;font-size:12px;white-space:pre;">,</span><span style="font-family:Consolas, &quot;Courier New&quot;, monospace;font-size:12px;white-space:pre;color:rgb(163, 21, 21);">'Lower&nbsp;middle&nbsp;income'</span>

-- %%
delete 
  FROM [COVID].[dbo].[owid-covid-data]
  where location in ('High income','Upper middle income','Lower middle income')
-- Out:
-- (2175 rows affected)
-- Total execution time: 00:00:00.061

-- %% [markdown]
-- ### Making sure the data is properly deleted in the source table

-- %%
select *
  FROM [COVID].[dbo].[owid-covid-data]
  where location in ('High income','Upper middle income','Lower middle income')
-- Out:
-- (0 rows affected)
-- Total execution time: 00:00:00.104
-- ...

-- %% [markdown]
-- # **Observations:**
--
-- ### From the above Data Analysis, it is observed that the Impact on the human body is very less when you are vaccinated and it gives you protection from the COVID. It is important to wear a mask even if you are vaccinated to protect yourself and others. Though the interviews done from various states asking if they are willing to wear mask as a protection, many states show they always willing to wear a mask to protect themselves and others.
--
-- ### If you observe the trend in the analysis gathered from the state of california, the unvaccinated deaths are always way higher than the vaccinated deaths. People unvaccinated who admitted in hospital are way higher than people joining hospital after being vaccinated.
--
-- ### Up on analyzing from various real world data from different sources, it is proven that Vaccinated are baing protected and have a longer survival rates when compared with unvaccinated.
--
-- ## **Take the Covid shot and booster to protect yourself and others from this enemy!**
--
-- ![Corona Virus Covid GIF - Corona Virus Covid Corona GIFs](https://c.tenor.com/f4Dz1iQCNE8AAAAC/corona-virus-covid.gif)
--
-- # **Conclusion:**
--
-- ### Up on reviewing and analyzing the COVID data, it is advised and suggested all employees to take vaccinations to protect their families and communites around them.Continue to wear a mask in a proper way and save yourself and others from COVID.
--
-- ### _**It doesn't cost you to protect your life but it does cost your life if you are not protected!**_
